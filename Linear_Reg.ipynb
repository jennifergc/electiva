# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors as mcolors

# %%
# Preprocessing Input data
data = pd.read_csv('ventas.csv')
X = data.iloc[:, 0]
Y = data.iloc[:, 1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-4d1c33496e6e> in <module>
#       1 # Preprocessing Input data
# ----> 2 data = pd.read_csv('ventas.csv')
#       3 X = data.iloc[:, 0]
#       4 Y = data.iloc[:, 1]
#
# NameError: name 'pd' is not defined

# %%
#plt.plot(data[:,0],data[:,1])
data = np.loadtxt("ventas.dat")
X = data[:, 0]
Y = data[:, 1]

# %%
#plotting the data

plt.figure()
plt.scatter(X,Y)
plt.xlabel("TV [m]")
plt.ylabel("Ventas")
plt.grid()
plt.show()

# %%
# Building the model
X_mean = np.mean(X)
Y_mean = np.mean(Y)

num = 0
den = 0
for i in range(len(X)):
    num += (X[i] - X_mean)*(Y[i] - Y_mean)
    den += (X[i] - X_mean)**2
m = num / den
c = Y_mean - m*X_mean

print (m, c)
# Out:
# 0.04736169244658102 7.085891408958309

# %%
# Making predictions
Y_pred = m*X + c

plt.scatter(X, Y) # actual
# plt.scatter(X, Y_pred, color='red')
plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='red') # predicted
plt.show()
